# %% [markdown]
# --- Part Two ---
# While The Historians begin working around the guard's patrol route, you borrow their fancy device and step outside the lab. From the safety of a supply closet, you time travel through the last few months and record the nightly status of the lab's guard post on the walls of the closet.
#
# Returning after what seems like only a few seconds to The Historians, they explain that the guard's patrol area is simply too large for them to safely search the lab without getting caught.
#
# Fortunately, they are pretty sure that adding a single new obstruction won't cause a time paradox. They'd like to place the new obstruction in such a way that the guard will get stuck in a loop, making the rest of the lab safe to search.
#
# To have the lowest chance of creating a time paradox, The Historians would like to know all of the possible positions for such an obstruction. The new obstruction can't be placed at the guard's starting position - the guard is there right now and would notice.
#
# In the above example, there are only 6 different positions where a new obstruction would cause the guard to get stuck in a loop. The diagrams of these six situations use O to mark the new obstruction, | to show a position where the guard moves up/down, - to show a position where the guard moves left/right, and + to show a position where the guard moves both up/down and left/right.

# %%
guard_characters = ["^", ">", "V", "<"]
pathing_chars = ["-", "|", "+"]
initial_grid = [
    "....#.....",
    ".........#",
    "..........",
    "..#.......",
    ".......#..",
    "..........",
    ".#..^.....",
    "........#.",
    "#.........",
    "......#...",
]
initial_grid = [list(row) for row in initial_grid]
initial_guard_loc_x = 0
initial_guard_loc_y = 0
initial_guard_direction = "^"

# %%
def get_file_content():
    with open("day-6-input.txt", "r") as file:
        # Read all lines and strip any trailing newlines or spaces
        grid = [line.strip() for line in file]
        grid = [list(row) for row in grid]
    return grid


initial_grid = get_file_content()

# %%
for y in range(len(initial_grid)):
    for x in range(len(initial_grid[y])):
        if initial_grid[y][x] in guard_characters:
            initial_guard_loc_x = x
            initial_guard_loc_y = y
            initial_guard_direction = initial_grid[y][x]


def get_movement_dir(guard_dir):
    match guard_dir:
        case "^":
            return (0, -1, "|")
        case ">":
            return (1, 0, "-")
        case "V":
            return (0, 1, "|")
        case "<":
            return (-1, 0, "-")
        case _:
            return (0, 0, ".")


def get_lookahead(guard_loc_x, guard_loc_y, offset, grid, reference_char=["#"]):
    value = grid[guard_loc_y + offset[1]][guard_loc_x + offset[0]]
    return value not in reference_char


def get_next_direction(guard_direction):
    index_of_direction = guard_characters.index(guard_direction)
    try:
        return guard_characters[index_of_direction + 1]
    except IndexError:
        return guard_characters[0]


def mutate_grid(x, y, grid, char):
    grid[y][x] = char
    return grid


def change_to_tracked(guard_loc_x, guard_loc_y, grid, direction_character):
    current_char = grid[guard_loc_y][guard_loc_x]
    if current_char in pathing_chars:
        direction_character = "+"
    grid = mutate_grid(guard_loc_x, guard_loc_y, grid, direction_character)
    return grid


def print_grid(grid):
    for line in grid:
        print(line)
    print("-----------")


def move_forward(guard_loc_x, guard_loc_y, guard_direction, grid, loop_references):
    offset = (0, 0, ".")
    can_move_forward = False
    has_turned = False
    while can_move_forward == False:
        offset = get_movement_dir(guard_direction)
        can_move_forward = get_lookahead(
            guard_loc_x, guard_loc_y, offset, grid, ["#", "O"]
        )
        if can_move_forward == False:
            has_turned = True
            guard_direction = get_next_direction(guard_direction)
            if (guard_loc_y, guard_loc_x, guard_direction) in loop_references:
                raise Exception("Closed loop")
            else:
                loop_references.append((guard_loc_y, guard_loc_x, guard_direction))

    grid = change_to_tracked(
        guard_loc_x, guard_loc_y, grid, "+" if has_turned else offset[2]
    )
    guard_loc_y = guard_loc_y + offset[1]
    guard_loc_x = guard_loc_x + offset[0]
    return (guard_loc_x, guard_loc_y, guard_direction, grid, loop_references)

# %%
import copy


def run_full_analysis(guard_loc_x, guard_loc_y, guard_direction, grid):
    loop_references = []
    while True:
        try:
            guard_loc_x, guard_loc_y, guard_direction, grid, loop_references = (
                move_forward(
                    guard_loc_x, guard_loc_y, guard_direction, grid, loop_references
                )
            )
        except IndexError:
            dir_char = get_movement_dir(guard_direction)
            grid = change_to_tracked(guard_loc_x, guard_loc_y, grid, dir_char[2])
            break
        except Exception as e:
            print("CLOSED LOOP")
            return (1, grid)

    return (0, grid)

# %%
end_count = 0
end_count, check_grid = run_full_analysis(
    initial_guard_loc_x, initial_guard_loc_y, initial_guard_direction, copy.deepcopy(initial_grid)
)

# %%
for y in range(len(initial_grid)):
    for x in range(len(initial_grid[y])):
        if check_grid[y][x] in pathing_chars:
            grid, guard_loc_x, guard_loc_y, guard_direction = (
                copy.deepcopy(initial_grid),
                initial_guard_loc_x,
                initial_guard_loc_y,
                initial_guard_direction,
            )
            grid = mutate_grid(x, y, grid, "O")
            outcome, grid = run_full_analysis(
                guard_loc_x, guard_loc_y, guard_direction, grid
            )
            end_count += outcome
            print(f"completed run {y}, {x}")

print(end_count)
# Out:
# CLOSED LOOP
# completed run 4, 31
# CLOSED LOOP
# completed run 4, 32
# completed run 4, 33
# completed run 4, 34
# CLOSED LOOP
# completed run 4, 35
# completed run 4, 36
# completed run 4, 37
# CLOSED LOOP
# completed run 4, 38
# CLOSED LOOP
# completed run 4, 39
# CLOSED LOOP
# completed run 4, 40
# completed run 4, 41
# CLOSED LOOP
# completed run 4, 42
# completed run 4, 43
# completed run 4, 44
# CLOSED LOOP
# completed run 4, 45
# CLOSED LOOP
# completed run 4, 46
# completed run 4, 47
# completed run 4, 48
# completed run 4, 49
# completed run 4, 50
# completed run 4, 51
# completed run 4, 52
# completed run 4, 53
# CLOSED LOOP
# completed run 4, 54
# completed run 4, 55
# CLOSED LOOP
# completed run 4, 56
# CLOSED LOOP
# completed run 4, 57
# CLOSED LOOP
# completed run 4, 58
# CLOSED LOOP
# completed run 4, 59
# completed run 4, 60
# CLOSED LOOP
# completed run 4, 61
# CLOSED LOOP
# completed run 4, 62
# CLOSED LOOP
# completed run 4, 63
# CLOSED LOOP
# completed run 4, 64
# CLOSED LOOP
# completed run 4, 65
# CLOSED LOOP
# completed run 4, 66
# CLOSED LOOP
# completed run 4, 67
# completed run 4, 68
# completed run 4, 69
# completed run 4, 70
# completed run 4, 71
# completed run 4, 72
# completed run 4, 73
# completed run 5, 31
# CLOSED LOOP
# completed run 5, 73
# completed run 6, 9
# completed run 6, 10
# CLOSED LOOP
# completed run 6, 11
# CLOSED LOOP
# completed run 6, 12
# CLOSED LOOP
# completed run 6, 13
# CLOSED LOOP
# completed run 6, 14
# CLOSED LOOP
# completed run 6, 15
# CLOSED LOOP
# completed run 6, 16
# completed run 6, 17
# completed run 6, 18
# CLOSED LOOP
# completed run 6, 19
# CLOSED LOOP
# completed run 6, 20
# completed run 6, 21
# CLOSED LOOP
# completed run 6, 22
# completed run 6, 23
# CLOSED LOOP
# completed run 6, 24
# completed run 6, 25
# CLOSED LOOP
# completed run 6, 26
# completed run 6, 27
# completed run 6, 28
# CLOSED LOOP
# completed run 6, 29
# CLOSED LOOP
# completed run 6, 30
# CLOSED LOOP
# completed run 6, 31
# CLOSED LOOP
# completed run 6, 32
# completed run 6, 33
# completed run 6, 34
# CLOSED LOOP
# completed run 6, 35
# completed run 6, 36
# completed run 6, 37
# CLOSED LOOP
# completed run 6, 38
# CLOSED LOOP
# completed run 6, 39
# CLOSED LOOP
# completed run 6, 40
# completed run 6, 41
# CLOSED LOOP
# completed run 6, 42
# completed run 6, 43
# completed run 6, 44
# CLOSED LOOP
# completed run 6, 45
# CLOSED LOOP
# completed run 6, 46
# completed run 6, 47
# CLOSED LOOP
# completed run 6, 48
# completed run 6, 49
# completed run 6, 50
# completed run 6, 51
# completed run 6, 52
# completed run 6, 53
# CLOSED LOOP
# completed run 6, 54
# CLOSED LOOP
# completed run 6, 55
# CLOSED LOOP
# completed run 6, 56
# CLOSED LOOP
# completed run 6, 57
# CLOSED LOOP
# completed run 6, 58
# CLOSED LOOP
# completed run 6, 59
# completed run 6, 60
# CLOSED LOOP
# completed run 6, 61
# CLOSED LOOP
# completed run 6, 62
# CLOSED LOOP
# completed run 6, 63
# CLOSED LOOP
# completed run 6, 64
# CLOSED LOOP
# completed run 6, 65
# CLOSED LOOP
# completed run 6, 66
# CLOSED LOOP
# completed run 6, 67
# completed run 6, 73
# completed run 7, 9
# completed run 7, 31
# completed run 7, 67
# completed run 7, 73
# CLOSED LOOP
# completed run 8, 9
# CLOSED LOOP
# completed run 8, 31
# completed run 8, 67
# completed run 8, 73
# CLOSED LOOP
# completed run 8, 95
# CLOSED LOOP
# completed run 8, 96
# CLOSED LOOP
# completed run 8, 97
# completed run 8, 98
# CLOSED LOOP
# completed run 8, 99
# CLOSED LOOP
# completed run 8, 100
# completed run 8, 101
# CLOSED LOOP
# completed run 8, 102
# completed run 8, 103
# CLOSED LOOP
# completed run 8, 104
# CLOSED LOOP
# completed run 8, 105
# CLOSED LOOP
# completed run 8, 106
# CLOSED LOOP
# completed run 8, 107
# completed run 8, 108
# completed run 8, 109
# completed run 8, 110
# CLOSED LOOP
# completed run 8, 111
# completed run 8, 112
# CLOSED LOOP
# completed run 8, 113
# CLOSED LOOP
# completed run 8, 114
# completed run 8, 115
# CLOSED LOOP
# completed run 8, 116
# CLOSED LOOP
# completed run 8, 117
# CLOSED LOOP
# completed run 8, 118
# completed run 8, 119
# completed run 8, 120
# completed run 8, 121
# completed run 8, 122
# completed run 8, 123
# CLOSED LOOP
# completed run 8, 124
# completed run 8, 125
# completed run 8, 126
# completed run 8, 127
# completed run 9, 9
# completed run 9, 10
# CLOSED LOOP
# completed run 9, 11
# completed run 9, 12
# CLOSED LOOP
# completed run 9, 13
# completed run 9, 14
# completed run 9, 15
# completed run 9, 16
# CLOSED LOOP
# completed run 9, 17
# completed run 9, 18
# completed run 9, 19
# completed run 9, 20
# completed run 9, 21
# CLOSED LOOP
# completed run 9, 22
# completed run 9, 23
# completed run 9, 24
# CLOSED LOOP
# completed run 9, 25
# CLOSED LOOP
# completed run 9, 26
# CLOSED LOOP
# completed run 9, 27
# CLOSED LOOP
# completed run 9, 28
# CLOSED LOOP
# completed run 9, 29
# CLOSED LOOP
# completed run 9, 30
# completed run 9, 31
# completed run 9, 32
# completed run 9, 33
# completed run 9, 34
# completed run 9, 35
# CLOSED LOOP
# completed run 9, 36
# CLOSED LOOP
# completed run 9, 37
# completed run 9, 38
# completed run 9, 39
# completed run 9, 40
# CLOSED LOOP
# completed run 9, 41
# CLOSED LOOP
# completed run 9, 42
# completed run 9, 43
# completed run 9, 44
# completed run 9, 45
# CLOSED LOOP
# completed run 9, 46
# completed run 9, 47
# completed run 9, 48
# completed run 9, 49
# CLOSED LOOP
# completed run 9, 50
# CLOSED LOOP
# completed run 9, 51
# completed run 9, 52
# CLOSED LOOP
# completed run 9, 53
# CLOSED LOOP
# completed run 9, 54
# completed run 9, 55
# completed run 9, 56
# completed run 9, 57
# CLOSED LOOP
# completed run 9, 58
# CLOSED LOOP
# completed run 9, 59
# completed run 9, 60
# completed run 9, 61
# completed run 9, 62
# completed run 9, 63
# CLOSED LOOP
# completed run 9, 64
# completed run 9, 65
# completed run 9, 66
# completed run 9, 67
# completed run 9, 68
# completed run 9, 69
# completed run 9, 70
# CLOSED LOOP
# completed run 9, 71
# CLOSED LOOP
# completed run 9, 72
# CLOSED LOOP
# completed run 9, 73
# CLOSED LOOP
# completed run 9, 95
# CLOSED LOOP
# completed run 9, 127
# completed run 10, 31
# CLOSED LOOP
# completed run 10, 67
# completed run 10, 95
# completed run 10, 127
# completed run 11, 31
# CLOSED LOOP
# completed run 11, 67
# completed run 11, 95
# completed run 11, 127
# CLOSED LOOP
# completed run 12, 31
# completed run 12, 67
# completed run 12, 95
# completed run 12, 127
# completed run 13, 3
# CLOSED LOOP
# completed run 13, 4
# completed run 13, 5
# CLOSED LOOP
# completed run 13, 6
# CLOSED LOOP
# completed run 13, 7
# CLOSED LOOP
# completed run 13, 8
# CLOSED LOOP
# completed run 13, 9
# completed run 13, 10
# CLOSED LOOP
# completed run 13, 11
# CLOSED LOOP
# completed run 13, 12
# CLOSED LOOP
# completed run 13, 13
# CLOSED LOOP
# completed run 13, 14
# completed run 13, 15
# completed run 13, 16
# CLOSED LOOP
# completed run 13, 17
# completed run 13, 18
# CLOSED LOOP
# completed run 13, 19
# CLOSED LOOP
# completed run 13, 20
# completed run 13, 21
# CLOSED LOOP
# completed run 13, 22
# completed run 13, 23
# CLOSED LOOP
# completed run 13, 24
# completed run 13, 25
# CLOSED LOOP
# completed run 13, 26
# completed run 13, 27
# completed run 13, 28
# CLOSED LOOP
# completed run 13, 29
# CLOSED LOOP
# completed run 13, 30
# completed run 13, 31
# CLOSED LOOP
# completed run 13, 32
# completed run 13, 33
# completed run 13, 34
# CLOSED LOOP
# completed run 13, 35
# completed run 13, 36
# completed run 13, 37
# CLOSED LOOP
# completed run 13, 38
# CLOSED LOOP
# completed run 13, 39
# CLOSED LOOP
# completed run 13, 40
# completed run 13, 41
# CLOSED LOOP
# completed run 13, 42
# completed run 13, 43
# completed run 13, 44
# CLOSED LOOP
# completed run 13, 45
# CLOSED LOOP
# completed run 13, 46
# completed run 13, 47
# CLOSED LOOP
# completed run 13, 48
# completed run 13, 49
# completed run 13, 50
# completed run 13, 51
# completed run 13, 52
# completed run 13, 53
# CLOSED LOOP
# completed run 13, 54
# completed run 13, 55
# CLOSED LOOP
# completed run 13, 56
# CLOSED LOOP
# completed run 13, 57
# CLOSED LOOP
# completed run 13, 58
# CLOSED LOOP
# completed run 13, 59
# completed run 13, 60
# CLOSED LOOP
# completed run 13, 61
# CLOSED LOOP
# completed run 13, 62
# CLOSED LOOP
# completed run 13, 63
# CLOSED LOOP
# completed run 13, 64
# CLOSED LOOP
# completed run 13, 65
# CLOSED LOOP
# completed run 13, 67
# CLOSED LOOP
# completed run 13, 95
# completed run 13, 127
# completed run 14, 3
# CLOSED LOOP
# completed run 14, 31
# completed run 14, 65
# completed run 14, 67
# completed run 14, 95
# completed run 14, 127
# completed run 15, 3
# CLOSED LOOP
# completed run 15, 31
# CLOSED LOOP
# completed run 15, 65
# CLOSED LOOP
# completed run 15, 67
# completed run 15, 95
# completed run 15, 127
# completed run 16, 3
# completed run 16, 31
# completed run 16, 40
# completed run 16, 41
# completed run 16, 42
# completed run 16, 43
# completed run 16, 44
# completed run 16, 45
# completed run 16, 46
# completed run 16, 47
# completed run 16, 48
# CLOSED LOOP
# completed run 16, 49
# completed run 16, 50
# completed run 16, 51
# completed run 16, 52
# completed run 16, 53
# CLOSED LOOP
# completed run 16, 54
# completed run 16, 55
# completed run 16, 56
# completed run 16, 57
# completed run 16, 58
# completed run 16, 59
# CLOSED LOOP
# completed run 16, 60
# completed run 16, 61
# completed run 16, 62
# CLOSED LOOP
# completed run 16, 63
# completed run 16, 64
# CLOSED LOOP
# completed run 16, 65
# completed run 16, 66
# completed run 16, 67
# completed run 16, 68
# completed run 16, 69
# completed run 16, 70
# completed run 16, 71
# completed run 16, 72
# completed run 16, 73
# completed run 16, 74
# completed run 16, 75
# completed run 16, 76
# completed run 16, 77
# CLOSED LOOP
# completed run 16, 78
# CLOSED LOOP
# completed run 16, 79
# CLOSED LOOP
# completed run 16, 80
# completed run 16, 81
# completed run 16, 82
# completed run 16, 83
# completed run 16, 84
# completed run 16, 85
# CLOSED LOOP
# completed run 16, 86
# completed run 16, 87
# CLOSED LOOP
# completed run 16, 88
# CLOSED LOOP
# completed run 16, 89
# completed run 16, 90
# completed run 16, 91
# completed run 16, 92
# completed run 16, 95
# completed run 16, 127
# completed run 17, 3
# completed run 17, 31
# completed run 17, 40
# completed run 17, 65
# completed run 17, 67
# completed run 17, 92
# CLOSED LOOP
# completed run 17, 95
# completed run 17, 124
# CLOSED LOOP
# completed run 17, 125
# completed run 17, 126
# completed run 17, 127
# CLOSED LOOP
# completed run 17, 128
# CLOSED LOOP
# completed run 17, 129
# completed run 18, 3
# completed run 18, 31
# completed run 18, 40
# CLOSED LOOP
# completed run 18, 65
# CLOSED LOOP
# completed run 18, 66
# completed run 18, 67
# CLOSED LOOP
# completed run 18, 68
# CLOSED LOOP
# completed run 18, 69
# CLOSED LOOP
# completed run 18, 70
# CLOSED LOOP
# completed run 18, 71
# CLOSED LOOP
# completed run 18, 72
# CLOSED LOOP
# completed run 18, 73
# CLOSED LOOP
# completed run 18, 74
# CLOSED LOOP
# completed run 18, 75
# CLOSED LOOP
# completed run 18, 76
# CLOSED LOOP
# completed run 18, 77
# CLOSED LOOP
# completed run 18, 78
# CLOSED LOOP
# completed run 18, 79
# CLOSED LOOP
# completed run 18, 80
# completed run 18, 81
# CLOSED LOOP
# completed run 18, 82
# completed run 18, 83
# CLOSED LOOP
# completed run 18, 84
# CLOSED LOOP
# completed run 18, 85
# CLOSED LOOP
# completed run 18, 86
# CLOSED LOOP
# completed run 18, 87
# CLOSED LOOP
# completed run 18, 88
# CLOSED LOOP
# completed run 18, 89
# CLOSED LOOP
# completed run 18, 90
# completed run 18, 91
# completed run 18, 92
# CLOSED LOOP
# completed run 18, 93
# CLOSED LOOP
# completed run 18, 94
# completed run 18, 95
# CLOSED LOOP
# completed run 18, 96
# completed run 18, 97
# completed run 18, 98
# CLOSED LOOP
# completed run 18, 99
# completed run 18, 100
# CLOSED LOOP
# completed run 18, 101
# completed run 18, 124
# completed run 18, 127
# completed run 19, 3
# completed run 19, 31
# completed run 19, 40
# CLOSED LOOP
# completed run 19, 65
# CLOSED LOOP
# completed run 19, 66
# CLOSED LOOP
# completed run 19, 67
# completed run 19, 92
# CLOSED LOOP
# completed run 19, 95
# CLOSED LOOP
# completed run 19, 101
# completed run 19, 124
# completed run 19, 127
# completed run 20, 3
# CLOSED LOOP
# completed run 20, 19
# CLOSED LOOP
# completed run 20, 20
# completed run 20, 21
# CLOSED LOOP
# completed run 20, 22
# completed run 20, 23
# CLOSED LOOP
# completed run 20, 24
# CLOSED LOOP
# completed run 20, 25
# CLOSED LOOP
# completed run 20, 26
# completed run 20, 27
# completed run 20, 28
# completed run 20, 29
# CLOSED LOOP
# completed run 20, 30
# completed run 20, 31
# CLOSED LOOP
# completed run 20, 32
# completed run 20, 33
# completed run 20, 34
# CLOSED LOOP
# completed run 20, 35
# completed run 20, 40
# CLOSED LOOP
# completed run 20, 57
# CLOSED LOOP
# completed run 20, 58
# CLOSED LOOP
# completed run 20, 59
# CLOSED LOOP
# completed run 20, 60
# CLOSED LOOP
# completed run 20, 61
# CLOSED LOOP
# completed run 20, 62
# CLOSED LOOP
# completed run 20, 63
# CLOSED LOOP
# completed run 20, 64
# CLOSED LOOP
# completed run 20, 65
# CLOSED LOOP
# completed run 20, 66
# CLOSED LOOP
# completed run 20, 67
# CLOSED LOOP
# completed run 20, 68
# CLOSED LOOP
# completed run 20, 69
# completed run 20, 70
# completed run 20, 71
# CLOSED LOOP
# completed run 20, 72
# completed run 20, 73
# CLOSED LOOP
# completed run 20, 74
# completed run 20, 75
# CLOSED LOOP
# completed run 20, 76
# CLOSED LOOP
# completed run 20, 77
# CLOSED LOOP
# completed run 20, 78
# CLOSED LOOP
# completed run 20, 79
# CLOSED LOOP
# completed run 20, 80
# completed run 20, 81
# CLOSED LOOP
# completed run 20, 82
# completed run 20, 83
# completed run 20, 92
# completed run 20, 95
# completed run 20, 101
# completed run 20, 124
# completed run 20, 127
# completed run 21, 3
# CLOSED LOOP
# completed run 21, 19
# CLOSED LOOP
# completed run 21, 31
# CLOSED LOOP
# completed run 21, 35
# CLOSED LOOP
# completed run 21, 40
# completed run 21, 47
# completed run 21, 48
# CLOSED LOOP
# completed run 21, 49
# completed run 21, 50
# completed run 21, 51
# completed run 21, 52
# completed run 21, 53
# completed run 21, 54
# completed run 21, 55
# completed run 21, 56
# CLOSED LOOP
# completed run 21, 57
# CLOSED LOOP
# completed run 21, 58
# completed run 21, 59
# completed run 21, 60
# completed run 21, 61
# completed run 21, 62
# completed run 21, 63
# completed run 21, 64
# CLOSED LOOP
# completed run 21, 65
# CLOSED LOOP
# completed run 21, 66
# CLOSED LOOP
# completed run 21, 67
# completed run 21, 68
# completed run 21, 69
# completed run 21, 70
# completed run 21, 71
# completed run 21, 72
# completed run 21, 73
# completed run 21, 74
# completed run 21, 75
# completed run 21, 76
# completed run 21, 77
# CLOSED LOOP
# completed run 21, 83
# completed run 21, 92
# CLOSED LOOP
# completed run 21, 95
# completed run 21, 101
# CLOSED LOOP
# completed run 21, 124
# completed run 21, 127
# completed run 22, 3
# completed run 22, 19
# CLOSED LOOP
# completed run 22, 31
# completed run 22, 32
# completed run 22, 33
# completed run 22, 34
# CLOSED LOOP
# completed run 22, 35
# CLOSED LOOP
# completed run 22, 36
# CLOSED LOOP
# completed run 22, 37
# CLOSED LOOP
# completed run 22, 38
# CLOSED LOOP
# completed run 22, 39
# completed run 22, 40
# CLOSED LOOP
# completed run 22, 41
# CLOSED LOOP
# completed run 22, 42
# CLOSED LOOP
# completed run 22, 43
# completed run 22, 44
# CLOSED LOOP
# completed run 22, 45
# CLOSED LOOP
# completed run 22, 46
# completed run 22, 47
# completed run 22, 48
# completed run 22, 49
# completed run 22, 50
# completed run 22, 51
# CLOSED LOOP
# completed run 22, 52
# CLOSED LOOP
# completed run 22, 53
# CLOSED LOOP
# completed run 22, 54
# completed run 22, 55
# completed run 22, 56
# completed run 22, 57
# CLOSED LOOP
# completed run 22, 58
# CLOSED LOOP
# completed run 22, 59
# completed run 22, 60
# completed run 22, 61
# completed run 22, 62
# CLOSED LOOP
# completed run 22, 63
# completed run 22, 64
# completed run 22, 65
# CLOSED LOOP
# completed run 22, 66
# completed run 22, 67
# completed run 22, 77
# completed run 22, 83
# completed run 22, 92
# CLOSED LOOP
# completed run 22, 95
# completed run 22, 101
# completed run 22, 124
# CLOSED LOOP
# completed run 22, 127
# completed run 23, 3
# completed run 23, 19
# CLOSED LOOP
# completed run 23, 35
# completed run 23, 40
# completed run 23, 47
# CLOSED LOOP
# completed run 23, 57
# completed run 23, 66
# CLOSED LOOP
# completed run 23, 67
# completed run 23, 77
# CLOSED LOOP
# completed run 23, 83
# completed run 23, 92
# CLOSED LOOP
# completed run 23, 95
# completed run 23, 101
# completed run 23, 124
# completed run 23, 127
# CLOSED LOOP
# completed run 24, 3
# CLOSED LOOP
# completed run 24, 19
# completed run 24, 35
# CLOSED LOOP
# completed run 24, 40
# completed run 24, 47
# CLOSED LOOP
# completed run 24, 57
# CLOSED LOOP
# completed run 24, 66
# completed run 24, 67
# completed run 24, 77
# completed run 24, 83
# completed run 24, 92
# CLOSED LOOP
# completed run 24, 95
# completed run 24, 101
# completed run 24, 124
# completed run 24, 127
# completed run 25, 3
# completed run 25, 19
# completed run 25, 35
# completed run 25, 40
# completed run 25, 47
# CLOSED LOOP
# completed run 25, 57
# completed run 25, 58
# completed run 25, 59
# completed run 25, 60
# completed run 25, 61
# completed run 25, 62
# completed run 25, 63
# completed run 25, 64
# completed run 25, 65
# completed run 25, 66
# CLOSED LOOP
# completed run 25, 67
# completed run 25, 68
# completed run 25, 69
# completed run 25, 70
# completed run 25, 71
# completed run 25, 72
# CLOSED LOOP
# completed run 25, 73
# completed run 25, 74
# CLOSED LOOP
# completed run 25, 75
# completed run 25, 76
# completed run 25, 77
# CLOSED LOOP
# completed run 25, 78
# completed run 25, 79
# completed run 25, 80
# completed run 25, 81
# completed run 25, 82
# completed run 25, 83
# completed run 25, 84
# completed run 25, 85
# CLOSED LOOP
# completed run 25, 86
# completed run 25, 87
# completed run 25, 88
# CLOSED LOOP
# completed run 25, 89
# completed run 25, 90
# completed run 25, 91
# completed run 25, 92
# completed run 25, 93
# completed run 25, 94
# completed run 25, 95
# completed run 25, 96
# completed run 25, 97
# completed run 25, 98
# completed run 25, 99
# completed run 25, 100
# CLOSED LOOP
# completed run 25, 101
# completed run 25, 102
# completed run 25, 103
# completed run 25, 104
# completed run 25, 105
# completed run 25, 124
# completed run 25, 127
# completed run 26, 3
# CLOSED LOOP
# completed run 26, 19
# CLOSED LOOP
# completed run 26, 35
# completed run 26, 40
# completed run 26, 47
# CLOSED LOOP
# completed run 26, 57
# completed run 26, 58
# CLOSED LOOP
# completed run 26, 66
# CLOSED LOOP
# completed run 26, 67
# completed run 26, 77
# CLOSED LOOP
# completed run 26, 83
# completed run 26, 92
# CLOSED LOOP
# completed run 26, 95
# CLOSED LOOP
# completed run 26, 101
# completed run 26, 105
# completed run 26, 124
# completed run 26, 127
# completed run 27, 3
# completed run 27, 19
# CLOSED LOOP
# completed run 27, 35
# completed run 27, 40
# CLOSED LOOP
# completed run 27, 46
# CLOSED LOOP
# completed run 27, 47
# CLOSED LOOP
# completed run 27, 48
# CLOSED LOOP
# completed run 27, 49
# CLOSED LOOP
# completed run 27, 50
# CLOSED LOOP
# completed run 27, 51
# CLOSED LOOP
# completed run 27, 52
# CLOSED LOOP
# completed run 27, 53
# CLOSED LOOP
# completed run 27, 54
# CLOSED LOOP
# completed run 27, 55
# CLOSED LOOP
# completed run 27, 56
# CLOSED LOOP
# completed run 27, 57
# CLOSED LOOP
# completed run 27, 58
# completed run 27, 59
# CLOSED LOOP
# completed run 27, 60
# CLOSED LOOP
# completed run 27, 61
# CLOSED LOOP
# completed run 27, 62
# CLOSED LOOP
# completed run 27, 63
# CLOSED LOOP
# completed run 27, 64
# CLOSED LOOP
# completed run 27, 65
# CLOSED LOOP
# completed run 27, 66
# CLOSED LOOP
# completed run 27, 67
# CLOSED LOOP
# completed run 27, 68
# completed run 27, 69
# completed run 27, 70
# CLOSED LOOP
# completed run 27, 71
# CLOSED LOOP
# completed run 27, 72
# CLOSED LOOP
# completed run 27, 73
# CLOSED LOOP
# completed run 27, 74
# CLOSED LOOP
# completed run 27, 75
# CLOSED LOOP
# completed run 27, 76
# CLOSED LOOP
# completed run 27, 77
# CLOSED LOOP
# completed run 27, 78
# CLOSED LOOP
# completed run 27, 79
# CLOSED LOOP
# completed run 27, 80
# completed run 27, 81
# CLOSED LOOP
# completed run 27, 82
# completed run 27, 83
# completed run 27, 84
# completed run 27, 85
# CLOSED LOOP
# completed run 27, 86
# completed run 27, 92
# completed run 27, 95
# completed run 27, 101
# completed run 27, 105
# completed run 27, 124
# completed run 27, 127
# CLOSED LOOP
# completed run 28, 3
# CLOSED LOOP
# completed run 28, 19
# CLOSED LOOP
# completed run 28, 35
# CLOSED LOOP
# completed run 28, 40
# CLOSED LOOP
# completed run 28, 46
# CLOSED LOOP
# completed run 28, 47
# CLOSED LOOP
# completed run 28, 57
# CLOSED LOOP
# completed run 28, 58
# CLOSED LOOP
# completed run 28, 66
# CLOSED LOOP
# completed run 28, 67
# completed run 28, 77
# CLOSED LOOP
# completed run 28, 83
# CLOSED LOOP
# completed run 28, 86
# completed run 28, 92
# CLOSED LOOP
# completed run 28, 95
# completed run 28, 101
# completed run 28, 105
# completed run 28, 124
# completed run 28, 127
# completed run 29, 3
# CLOSED LOOP
# completed run 29, 19
# CLOSED LOOP
# completed run 29, 35
# CLOSED LOOP
# completed run 29, 40
# completed run 29, 41
# completed run 29, 42
# completed run 29, 43
# completed run 29, 44
# completed run 29, 45
# CLOSED LOOP
# completed run 29, 46
# completed run 29, 47
# completed run 29, 48
# completed run 29, 49
# completed run 29, 50
# completed run 29, 51
# completed run 29, 52
# completed run 29, 53
# completed run 29, 54
# completed run 29, 55
# completed run 29, 56
# CLOSED LOOP
# completed run 29, 57
# completed run 29, 58
# completed run 29, 59
# completed run 29, 60
# completed run 29, 61
# completed run 29, 62
# completed run 29, 63
# completed run 29, 64
# completed run 29, 65
# CLOSED LOOP
# completed run 29, 66
# completed run 29, 67
# completed run 29, 68
# completed run 29, 69
# completed run 29, 70
# completed run 29, 71
# completed run 29, 72
# completed run 29, 73
# completed run 29, 74
# completed run 29, 75
# completed run 29, 76
# completed run 29, 77
# completed run 29, 78
# completed run 29, 79
# completed run 29, 80
# completed run 29, 81
# completed run 29, 82
# CLOSED LOOP
# completed run 29, 83
# completed run 29, 84
# completed run 29, 85
# CLOSED LOOP
# completed run 29, 86
# completed run 29, 87
# completed run 29, 88
# CLOSED LOOP
# completed run 29, 92
# CLOSED LOOP
# completed run 29, 95
# CLOSED LOOP
# completed run 29, 96
# CLOSED LOOP
# completed run 29, 97
# completed run 29, 98
# completed run 29, 99
# completed run 29, 100
# completed run 29, 101
# completed run 29, 105
# completed run 29, 124
# CLOSED LOOP
# completed run 29, 127
# completed run 30, 3
# CLOSED LOOP
# completed run 30, 19
# CLOSED LOOP
# completed run 30, 35
# completed run 30, 40
# completed run 30, 41
# CLOSED LOOP
# completed run 30, 46
# completed run 30, 47
# CLOSED LOOP
# completed run 30, 57
# completed run 30, 58
# CLOSED LOOP
# completed run 30, 66
# CLOSED LOOP
# completed run 30, 67
# completed run 30, 77
# CLOSED LOOP
# completed run 30, 83
# CLOSED LOOP
# completed run 30, 86
# completed run 30, 88
# completed run 30, 92
# completed run 30, 105
# CLOSED LOOP
# completed run 30, 124
# completed run 30, 127
# CLOSED LOOP
# completed run 31, 3
# CLOSED LOOP
# completed run 31, 19
# completed run 31, 35
# completed run 31, 40
# completed run 31, 41
# CLOSED LOOP
# completed run 31, 46
# completed run 31, 47
# CLOSED LOOP
# completed run 31, 57
# completed run 31, 58
# CLOSED LOOP
# completed run 31, 63
# CLOSED LOOP
# completed run 31, 64
# CLOSED LOOP
# completed run 31, 65
# CLOSED LOOP
# completed run 31, 66
# CLOSED LOOP
# completed run 31, 67
# CLOSED LOOP
# completed run 31, 68
# completed run 31, 69
# completed run 31, 70
# CLOSED LOOP
# completed run 31, 71
# CLOSED LOOP
# completed run 31, 72
# CLOSED LOOP
# completed run 31, 73
# CLOSED LOOP
# completed run 31, 74
# CLOSED LOOP
# completed run 31, 75
# CLOSED LOOP
# completed run 31, 76
# CLOSED LOOP
# completed run 31, 77
# CLOSED LOOP
# completed run 31, 78
# completed run 31, 79
# CLOSED LOOP
# completed run 31, 80
# completed run 31, 81
# CLOSED LOOP
# completed run 31, 82
# completed run 31, 83
# completed run 31, 84
# completed run 31, 85
# CLOSED LOOP
# completed run 31, 86
# completed run 31, 87
# CLOSED LOOP
# completed run 31, 88
# CLOSED LOOP
# completed run 31, 89
# CLOSED LOOP
# completed run 31, 92
# completed run 31, 105
# completed run 31, 124
# completed run 31, 127
# completed run 32, 3
# CLOSED LOOP
# completed run 32, 19
# completed run 32, 22
# completed run 32, 23
# completed run 32, 24
# completed run 32, 35
# CLOSED LOOP
# completed run 32, 40
# completed run 32, 41
# CLOSED LOOP
# completed run 32, 46
# completed run 32, 47
# CLOSED LOOP
# completed run 32, 57
# completed run 32, 58
# CLOSED LOOP
# completed run 32, 63
# CLOSED LOOP
# completed run 32, 66
# completed run 32, 67
# completed run 32, 77
# CLOSED LOOP
# completed run 32, 83
# CLOSED LOOP
# completed run 32, 86
# completed run 32, 88
# CLOSED LOOP
# completed run 32, 89
# completed run 32, 92
# completed run 32, 105
# completed run 32, 124
# completed run 32, 127
# completed run 33, 3
# CLOSED LOOP
# completed run 33, 19
# completed run 33, 22
# completed run 33, 24
# completed run 33, 27
# completed run 33, 28
# completed run 33, 29
# completed run 33, 30
# completed run 33, 31
# completed run 33, 32
# completed run 33, 33
# completed run 33, 34
# CLOSED LOOP
# completed run 33, 35
# completed run 33, 36
# completed run 33, 37
# completed run 33, 38
# completed run 33, 39
# CLOSED LOOP
# completed run 33, 40
# completed run 33, 41
# completed run 33, 42
# completed run 33, 43
# completed run 33, 44
# completed run 33, 45
# completed run 33, 46
# completed run 33, 47
# completed run 33, 48
# CLOSED LOOP
# completed run 33, 49
# completed run 33, 50
# completed run 33, 51
# completed run 33, 52
# CLOSED LOOP
# completed run 33, 53
# completed run 33, 54
# completed run 33, 55
# completed run 33, 56
# CLOSED LOOP
# completed run 33, 57
# completed run 33, 58
# completed run 33, 59
# completed run 33, 60
# completed run 33, 61
# completed run 33, 62
# completed run 33, 63
# CLOSED LOOP
# completed run 33, 64
# CLOSED LOOP
# completed run 33, 66
# CLOSED LOOP
# completed run 33, 67
# completed run 33, 77
# completed run 33, 83
# completed run 33, 86
# completed run 33, 88
# completed run 33, 89
# completed run 33, 92
# completed run 33, 105
# CLOSED LOOP
# completed run 33, 124
# CLOSED LOOP
# completed run 33, 127
# completed run 34, 3
# completed run 34, 19
# completed run 34, 22
# CLOSED LOOP
# completed run 34, 24
# completed run 34, 27
# CLOSED LOOP
# completed run 34, 35
# completed run 34, 40
# completed run 34, 41
# CLOSED LOOP
# completed run 34, 46
# completed run 34, 47
# CLOSED LOOP
# completed run 34, 57
# completed run 34, 58
# CLOSED LOOP
# completed run 34, 63
# completed run 34, 64
# CLOSED LOOP
# completed run 34, 66
# completed run 34, 67
# completed run 34, 77
# CLOSED LOOP
# completed run 34, 83
# CLOSED LOOP
# completed run 34, 86
# completed run 34, 88
# completed run 34, 89
# completed run 34, 92
# completed run 34, 105
# completed run 34, 124
# completed run 34, 127
# completed run 35, 3
# CLOSED LOOP
# completed run 35, 19
# completed run 35, 22
# completed run 35, 24
# CLOSED LOOP
# completed run 35, 27
# CLOSED LOOP
# completed run 35, 29
# completed run 35, 30
# CLOSED LOOP
# completed run 35, 31
# CLOSED LOOP
# completed run 35, 32
# CLOSED LOOP
# completed run 35, 33
# CLOSED LOOP
# completed run 35, 34
# CLOSED LOOP
# completed run 35, 35
# CLOSED LOOP
# completed run 35, 36
# CLOSED LOOP
# completed run 35, 37
# completed run 35, 38
# CLOSED LOOP
# completed run 35, 39
# CLOSED LOOP
# completed run 35, 40
# completed run 35, 41
# completed run 35, 42
# CLOSED LOOP
# completed run 35, 43
# completed run 35, 44
# CLOSED LOOP
# completed run 35, 45
# CLOSED LOOP
# completed run 35, 46
# CLOSED LOOP
# completed run 35, 47
# CLOSED LOOP
# completed run 35, 48
# CLOSED LOOP
# completed run 35, 49
# completed run 35, 50
# CLOSED LOOP
# completed run 35, 51
# CLOSED LOOP
# completed run 35, 52
# CLOSED LOOP
# completed run 35, 53
# CLOSED LOOP
# completed run 35, 54
# CLOSED LOOP
# completed run 35, 55
# CLOSED LOOP
# completed run 35, 56
# CLOSED LOOP
# completed run 35, 57
# CLOSED LOOP
# completed run 35, 58
# completed run 35, 59
# CLOSED LOOP
# completed run 35, 60
# CLOSED LOOP
# completed run 35, 61
# completed run 35, 62
# CLOSED LOOP
# completed run 35, 63
# CLOSED LOOP
# completed run 35, 64
# CLOSED LOOP
# completed run 35, 65
# CLOSED LOOP
# completed run 35, 66
# CLOSED LOOP
# completed run 35, 67
# CLOSED LOOP
# completed run 35, 68
# completed run 35, 69
# completed run 35, 70
# CLOSED LOOP
# completed run 35, 71
# CLOSED LOOP
# completed run 35, 72
# CLOSED LOOP
# completed run 35, 73
# CLOSED LOOP
# completed run 35, 74
# CLOSED LOOP
# completed run 35, 75
# CLOSED LOOP
# completed run 35, 76
# completed run 35, 77
# CLOSED LOOP
# completed run 35, 78
# completed run 35, 79
# CLOSED LOOP
# completed run 35, 80
# completed run 35, 81
# CLOSED LOOP
# completed run 35, 82
# completed run 35, 83
# completed run 35, 84
# completed run 35, 85
# CLOSED LOOP
# completed run 35, 86
# completed run 35, 87
# CLOSED LOOP
# completed run 35, 88
# CLOSED LOOP
# completed run 35, 89
# completed run 35, 90
# CLOSED LOOP
# completed run 35, 91
# completed run 35, 92
# CLOSED LOOP
# completed run 35, 93
# completed run 35, 94
# completed run 35, 95
# CLOSED LOOP
# completed run 35, 96
# completed run 35, 97
# completed run 35, 98
# CLOSED LOOP
# completed run 35, 99
# completed run 35, 100
# CLOSED LOOP
# completed run 35, 101
# CLOSED LOOP
# completed run 35, 102
# completed run 35, 103
# completed run 35, 105
# CLOSED LOOP
# completed run 35, 124
# completed run 35, 127
# CLOSED LOOP
# completed run 36, 3
# CLOSED LOOP
# completed run 36, 19
# CLOSED LOOP
# completed run 36, 22
# completed run 36, 24
# CLOSED LOOP
# completed run 36, 27
# CLOSED LOOP
# completed run 36, 29
# CLOSED LOOP
# completed run 36, 35
# CLOSED LOOP
# completed run 36, 40
# completed run 36, 41
# CLOSED LOOP
# completed run 36, 46
# CLOSED LOOP
# completed run 36, 47
# CLOSED LOOP
# completed run 36, 57
# CLOSED LOOP
# completed run 36, 58
# CLOSED LOOP
# completed run 36, 63
# completed run 36, 64
# CLOSED LOOP
# completed run 36, 66
# CLOSED LOOP
# completed run 36, 67
# completed run 36, 77
# CLOSED LOOP
# completed run 36, 83
# CLOSED LOOP
# completed run 36, 86
# completed run 36, 88
# CLOSED LOOP
# completed run 36, 89
# completed run 36, 92
# CLOSED LOOP
# completed run 36, 103
# completed run 36, 105
# completed run 36, 124
# completed run 36, 127
# CLOSED LOOP
# completed run 37, 3
# CLOSED LOOP
# completed run 37, 19
# completed run 37, 22
# completed run 37, 24
# completed run 37, 27
# CLOSED LOOP
# completed run 37, 29
# completed run 37, 33
# completed run 37, 34
# completed run 37, 35
# completed run 37, 36
# completed run 37, 37
# completed run 37, 38
# completed run 37, 39
# CLOSED LOOP
# completed run 37, 40
# completed run 37, 41
# completed run 37, 42
# completed run 37, 43
# completed run 37, 44
# completed run 37, 45
# CLOSED LOOP
# completed run 37, 46
# CLOSED LOOP
# completed run 37, 47
# completed run 37, 48
# CLOSED LOOP
# completed run 37, 49
# completed run 37, 50
# completed run 37, 51
# completed run 37, 52
# CLOSED LOOP
# completed run 37, 53
# completed run 37, 54
# completed run 37, 55
# completed run 37, 56
# CLOSED LOOP
# completed run 37, 57
# CLOSED LOOP
# completed run 37, 58
# completed run 37, 59
# completed run 37, 60
# completed run 37, 61
# completed run 37, 62
# completed run 37, 63
# CLOSED LOOP
# completed run 37, 64
# completed run 37, 65
# CLOSED LOOP
# completed run 37, 66
# CLOSED LOOP
# completed run 37, 67
# completed run 37, 68
# completed run 37, 69
# completed run 37, 70
# completed run 37, 71
# CLOSED LOOP
# completed run 37, 72
# completed run 37, 77
# completed run 37, 83
# completed run 37, 86
# completed run 37, 88
# completed run 37, 89
# completed run 37, 92
# completed run 37, 95
# completed run 37, 96
# completed run 37, 97
# completed run 37, 98
# CLOSED LOOP
# completed run 37, 99
# completed run 37, 100
# CLOSED LOOP
# completed run 37, 101
# CLOSED LOOP
# completed run 37, 102
# CLOSED LOOP
# completed run 37, 103
# CLOSED LOOP
# completed run 37, 104
# CLOSED LOOP
# completed run 37, 105
# CLOSED LOOP
# completed run 37, 106
# CLOSED LOOP
# completed run 37, 107
# completed run 37, 108
# completed run 37, 109
# completed run 37, 110
# completed run 37, 111
# completed run 37, 112
# completed run 37, 113
# CLOSED LOOP
# completed run 37, 114
# CLOSED LOOP
# completed run 37, 115
# CLOSED LOOP
# completed run 37, 116
# completed run 37, 124
# completed run 37, 127
# CLOSED LOOP
# completed run 38, 3
# CLOSED LOOP
# completed run 38, 19
# CLOSED LOOP
# completed run 38, 22
# completed run 38, 24
# completed run 38, 27
# CLOSED LOOP
# completed run 38, 29
# completed run 38, 33
# CLOSED LOOP
# completed run 38, 35
# CLOSED LOOP
# completed run 38, 40
# completed run 38, 41
# CLOSED LOOP
# completed run 38, 46
# completed run 38, 47
# CLOSED LOOP
# completed run 38, 57
# completed run 38, 58
# CLOSED LOOP
# completed run 38, 63
# completed run 38, 64
# CLOSED LOOP
# completed run 38, 66
# CLOSED LOOP
# completed run 38, 67
# completed run 38, 72
# completed run 38, 77
# CLOSED LOOP
# completed run 38, 83
# CLOSED LOOP
# completed run 38, 86
# CLOSED LOOP
# completed run 38, 88
# CLOSED LOOP
# completed run 38, 89
# completed run 38, 92
# CLOSED LOOP
# completed run 38, 95
# completed run 38, 103
# completed run 38, 105
# completed run 38, 116
# completed run 38, 124
# completed run 38, 127
# completed run 39, 3
# CLOSED LOOP
# completed run 39, 19
# completed run 39, 22
# CLOSED LOOP
# completed run 39, 24
# completed run 39, 27
# completed run 39, 29
# completed run 39, 31
# completed run 39, 32
# completed run 39, 33
# completed run 39, 34
# completed run 39, 35
# completed run 39, 36
# completed run 39, 37
# completed run 39, 38
# completed run 39, 39
# CLOSED LOOP
# completed run 39, 40
# completed run 39, 41
# completed run 39, 42
# completed run 39, 43
# completed run 39, 44
# completed run 39, 45
# CLOSED LOOP
# completed run 39, 46
# CLOSED LOOP
# completed run 39, 47
# CLOSED LOOP
# completed run 39, 48
# CLOSED LOOP
# completed run 39, 49
# completed run 39, 50
# completed run 39, 51
# completed run 39, 52
# CLOSED LOOP
# completed run 39, 53
# completed run 39, 54
# CLOSED LOOP
# completed run 39, 55
# completed run 39, 56
# CLOSED LOOP
# completed run 39, 57
# completed run 39, 58
# completed run 39, 59
# completed run 39, 60
# completed run 39, 61
# completed run 39, 62
# CLOSED LOOP
# completed run 39, 63
# CLOSED LOOP
# completed run 39, 64
# CLOSED LOOP
# completed run 39, 65
# CLOSED LOOP
# completed run 39, 66
# CLOSED LOOP
# completed run 39, 67
# completed run 39, 68
# completed run 39, 69
# completed run 39, 70
# CLOSED LOOP
# completed run 39, 72
# CLOSED LOOP
# completed run 39, 77
# CLOSED LOOP
# completed run 39, 83
# CLOSED LOOP
# completed run 39, 86
# completed run 39, 88
# completed run 39, 89
# completed run 39, 92
# completed run 39, 95
# completed run 39, 103
# completed run 39, 105
# CLOSED LOOP
# completed run 39, 116
# completed run 39, 124
# CLOSED LOOP
# completed run 39, 127
# CLOSED LOOP
# completed run 40, 3
# CLOSED LOOP
# completed run 40, 19
# CLOSED LOOP
# completed run 40, 22
# completed run 40, 24
# CLOSED LOOP
# completed run 40, 27
# CLOSED LOOP
# completed run 40, 29
# CLOSED LOOP
# completed run 40, 31
# CLOSED LOOP
# completed run 40, 33
# CLOSED LOOP
# completed run 40, 35
# CLOSED LOOP
# completed run 40, 40
# completed run 40, 41
# CLOSED LOOP
# completed run 40, 46
# CLOSED LOOP
# completed run 40, 47
# CLOSED LOOP
# completed run 40, 57
# CLOSED LOOP
# completed run 40, 58
# CLOSED LOOP
# completed run 40, 63
# completed run 40, 64
# CLOSED LOOP
# completed run 40, 66
# CLOSED LOOP
# completed run 40, 67
# completed run 40, 70
# completed run 40, 72
# completed run 40, 77
# CLOSED LOOP
# completed run 40, 83
# CLOSED LOOP
# completed run 40, 86
# CLOSED LOOP
# completed run 40, 88
# CLOSED LOOP
# completed run 40, 89
# CLOSED LOOP
# completed run 40, 92
# CLOSED LOOP
# completed run 40, 95
# CLOSED LOOP
# completed run 40, 103
# CLOSED LOOP
# completed run 40, 105
# completed run 40, 116
# completed run 40, 124
# completed run 40, 127
# completed run 41, 3
# completed run 41, 19
# completed run 41, 22
# completed run 41, 23
# completed run 41, 24
# completed run 41, 25
# completed run 41, 26
# completed run 41, 27
# completed run 41, 28
# CLOSED LOOP
# completed run 41, 29
# completed run 41, 30
# completed run 41, 31
# completed run 41, 32
# completed run 41, 33
# completed run 41, 34
# completed run 41, 35
# completed run 41, 36
# completed run 41, 37
# completed run 41, 38
# completed run 41, 39
# CLOSED LOOP
# completed run 41, 40
# completed run 41, 41
# completed run 41, 42
# completed run 41, 43
# completed run 41, 44
# completed run 41, 45
# CLOSED LOOP
# completed run 41, 46
# completed run 41, 47
# completed run 41, 48
# completed run 41, 49
# completed run 41, 50
# completed run 41, 51
# completed run 41, 52
# CLOSED LOOP
# completed run 41, 53
# completed run 41, 54
# CLOSED LOOP
# completed run 41, 55
# completed run 41, 56
# CLOSED LOOP
# completed run 41, 57
# completed run 41, 58
# completed run 41, 59
# completed run 41, 60
# completed run 41, 61
# completed run 41, 62
# CLOSED LOOP
# completed run 41, 63
# completed run 41, 64
# completed run 41, 65
# CLOSED LOOP
# completed run 41, 66
# completed run 41, 67
# completed run 41, 68
# completed run 41, 69
# completed run 41, 70
# completed run 41, 71
# completed run 41, 72
# completed run 41, 73
# completed run 41, 74
# completed run 41, 75
# completed run 41, 76
# completed run 41, 77
# completed run 41, 78
# completed run 41, 79
# completed run 41, 80
# completed run 41, 81
# completed run 41, 82
# CLOSED LOOP
# completed run 41, 83
# completed run 41, 84
# completed run 41, 85
# completed run 41, 86
# completed run 41, 87
# completed run 41, 88
# CLOSED LOOP
# completed run 41, 89
# completed run 41, 90
# completed run 41, 91
# completed run 41, 92
# completed run 41, 93
# completed run 41, 94
# completed run 41, 95
# completed run 41, 96
# completed run 41, 97
# completed run 41, 98
# completed run 41, 103
# completed run 41, 105
# completed run 41, 116
# completed run 41, 124
# CLOSED LOOP
# completed run 41, 127
# CLOSED LOOP
# completed run 42, 3
# completed run 42, 19
# completed run 42, 22
# completed run 42, 23
# completed run 42, 24
# completed run 42, 27
# completed run 42, 29
# completed run 42, 31
# completed run 42, 33
# CLOSED LOOP
# completed run 42, 35
# CLOSED LOOP
# completed run 42, 40
# completed run 42, 41
# CLOSED LOOP
# completed run 42, 46
# completed run 42, 47
# CLOSED LOOP
# completed run 42, 57
# completed run 42, 58
# CLOSED LOOP
# completed run 42, 63
# completed run 42, 64
# completed run 42, 66
# CLOSED LOOP
# completed run 42, 67
# completed run 42, 68
# CLOSED LOOP
# completed run 42, 69
# CLOSED LOOP
# completed run 42, 70
# CLOSED LOOP
# completed run 42, 71
# CLOSED LOOP
# completed run 42, 72
# CLOSED LOOP
# completed run 42, 73
# CLOSED LOOP
# completed run 42, 74
# CLOSED LOOP
# completed run 42, 75
# completed run 42, 76
# CLOSED LOOP
# completed run 42, 77
# completed run 42, 78
# CLOSED LOOP
# completed run 42, 79
# CLOSED LOOP
# completed run 42, 80
# CLOSED LOOP
# completed run 42, 81
# CLOSED LOOP
# completed run 42, 82
# CLOSED LOOP
# completed run 42, 83
# CLOSED LOOP
# completed run 42, 86
# completed run 42, 88
# CLOSED LOOP
# completed run 42, 89
# completed run 42, 92
# completed run 42, 95
# completed run 42, 98
# completed run 42, 103
# completed run 42, 105
# completed run 42, 116
# completed run 42, 124
# completed run 42, 127
# completed run 43, 3
# completed run 43, 19
# completed run 43, 22
# completed run 43, 23
# completed run 43, 24
# completed run 43, 27
# completed run 43, 29
# completed run 43, 31
# completed run 43, 33
# completed run 43, 35
# completed run 43, 40
# completed run 43, 41
# CLOSED LOOP
# completed run 43, 46
# CLOSED LOOP
# completed run 43, 47
# CLOSED LOOP
# completed run 43, 57
# CLOSED LOOP
# completed run 43, 58
# CLOSED LOOP
# completed run 43, 63
# completed run 43, 64
# completed run 43, 67
# completed run 43, 70
# completed run 43, 72
# completed run 43, 77
# completed run 43, 86
# completed run 43, 88
# completed run 43, 89
# completed run 43, 92
# CLOSED LOOP
# completed run 43, 95
# completed run 43, 98
# completed run 43, 103
# completed run 43, 105
# completed run 43, 116
# completed run 43, 124
# completed run 43, 127
# completed run 44, 3
# CLOSED LOOP
# completed run 44, 19
# CLOSED LOOP
# completed run 44, 22
# completed run 44, 23
# CLOSED LOOP
# completed run 44, 24
# completed run 44, 27
# completed run 44, 29
# completed run 44, 31
# completed run 44, 33
# CLOSED LOOP
# completed run 44, 35
# CLOSED LOOP
# completed run 44, 40
# completed run 44, 41
# CLOSED LOOP
# completed run 44, 46
# completed run 44, 47
# CLOSED LOOP
# completed run 44, 57
# completed run 44, 58
# CLOSED LOOP
# completed run 44, 63
# completed run 44, 64
# completed run 44, 67
# completed run 44, 70
# completed run 44, 72
# completed run 44, 77
# CLOSED LOOP
# completed run 44, 86
# completed run 44, 88
# CLOSED LOOP
# completed run 44, 89
# CLOSED LOOP
# completed run 44, 92
# completed run 44, 95
# completed run 44, 96
# completed run 44, 97
# completed run 44, 98
# CLOSED LOOP
# completed run 44, 99
# completed run 44, 100
# CLOSED LOOP
# completed run 44, 103
# completed run 44, 105
# completed run 44, 116
# completed run 44, 124
# completed run 44, 127
# completed run 45, 3
# completed run 45, 19
# completed run 45, 22
# completed run 45, 23
# completed run 45, 24
# completed run 45, 27
# CLOSED LOOP
# completed run 45, 29
# CLOSED LOOP
# completed run 45, 31
# CLOSED LOOP
# completed run 45, 33
# completed run 45, 35
# CLOSED LOOP
# completed run 45, 40
# completed run 45, 41
# CLOSED LOOP
# completed run 45, 46
# CLOSED LOOP
# completed run 45, 47
# completed run 45, 57
# completed run 45, 58
# completed run 45, 63
# completed run 45, 64
# CLOSED LOOP
# completed run 45, 67
# completed run 45, 70
# completed run 45, 72
# completed run 45, 77
# completed run 45, 86
# completed run 45, 88
# completed run 45, 89
# completed run 45, 92
# completed run 45, 95
# completed run 45, 96
# completed run 45, 98
# completed run 45, 100
# completed run 45, 103
# completed run 45, 105
# completed run 45, 116
# completed run 45, 124
# completed run 45, 127
# completed run 46, 3
# completed run 46, 19
# completed run 46, 22
# completed run 46, 23
# completed run 46, 24
# completed run 46, 27
# CLOSED LOOP
# completed run 46, 29
# completed run 46, 31
# completed run 46, 33
# completed run 46, 35
# completed run 46, 40
# completed run 46, 41
# CLOSED LOOP
# completed run 46, 46
# completed run 46, 47
# CLOSED LOOP
# completed run 46, 57
# completed run 46, 58
# completed run 46, 63
# completed run 46, 64
# completed run 46, 67
# completed run 46, 70
# completed run 46, 72
# completed run 46, 77
# completed run 46, 86
# completed run 46, 88
# completed run 46, 89
# completed run 46, 92
# completed run 46, 95
# completed run 46, 96
# completed run 46, 98
# completed run 46, 100
# completed run 46, 103
# completed run 46, 105
# completed run 46, 116
# completed run 46, 124
# completed run 46, 127
# completed run 47, 3
# completed run 47, 19
# completed run 47, 22
# completed run 47, 23
# completed run 47, 24
# completed run 47, 27
# completed run 47, 29
# completed run 47, 31
# completed run 47, 33
# completed run 47, 35
# completed run 47, 40
# completed run 47, 41
# CLOSED LOOP
# completed run 47, 46
# completed run 47, 47
# CLOSED LOOP
# completed run 47, 53
# completed run 47, 54
# CLOSED LOOP
# completed run 47, 55
# CLOSED LOOP
# completed run 47, 56
# CLOSED LOOP
# completed run 47, 57
# CLOSED LOOP
# completed run 47, 58
# CLOSED LOOP
# completed run 47, 59
# CLOSED LOOP
# completed run 47, 60
# completed run 47, 61
# completed run 47, 62
# CLOSED LOOP
# completed run 47, 63
# CLOSED LOOP
# completed run 47, 64
# CLOSED LOOP
# completed run 47, 65
# CLOSED LOOP
# completed run 47, 66
# CLOSED LOOP
# completed run 47, 67
# CLOSED LOOP
# completed run 47, 68
# completed run 47, 69
# CLOSED LOOP
# completed run 47, 70
# CLOSED LOOP
# completed run 47, 71
# CLOSED LOOP
# completed run 47, 72
# CLOSED LOOP
# completed run 47, 73
# completed run 47, 74
# completed run 47, 75
# CLOSED LOOP
# completed run 47, 76
# completed run 47, 77
# CLOSED LOOP
# completed run 47, 78
# CLOSED LOOP
# completed run 47, 79
# CLOSED LOOP
# completed run 47, 80
# CLOSED LOOP
# completed run 47, 81
# CLOSED LOOP
# completed run 47, 82
# CLOSED LOOP
# completed run 47, 83
# CLOSED LOOP
# completed run 47, 84
# CLOSED LOOP
# completed run 47, 85
# CLOSED LOOP
# completed run 47, 86
# CLOSED LOOP
# completed run 47, 87
# completed run 47, 88
# CLOSED LOOP
# completed run 47, 89
# CLOSED LOOP
# completed run 47, 90
# CLOSED LOOP
# completed run 47, 91
# CLOSED LOOP
# completed run 47, 92
# CLOSED LOOP
# completed run 47, 93
# completed run 47, 94
# CLOSED LOOP
# completed run 47, 95
# CLOSED LOOP
# completed run 47, 96
# completed run 47, 97
# completed run 47, 98
# CLOSED LOOP
# completed run 47, 99
# CLOSED LOOP
# completed run 47, 100
# CLOSED LOOP
# completed run 47, 101
# CLOSED LOOP
# completed run 47, 102
# CLOSED LOOP
# completed run 47, 103
# CLOSED LOOP
# completed run 47, 104
# completed run 47, 105
# CLOSED LOOP
# completed run 47, 106
# CLOSED LOOP
# completed run 47, 107
# completed run 47, 108
# completed run 47, 109
# completed run 47, 110
# completed run 47, 111
# CLOSED LOOP
# completed run 47, 112
# completed run 47, 113
# CLOSED LOOP
# completed run 47, 114
# CLOSED LOOP
# completed run 47, 115
# completed run 47, 116
# CLOSED LOOP
# completed run 47, 117
# completed run 47, 118
# completed run 47, 119
# completed run 47, 124
# completed run 47, 125
# completed run 47, 126
# completed run 47, 127
# completed run 48, 3
# completed run 48, 19
# completed run 48, 22
# completed run 48, 23
# completed run 48, 24
# completed run 48, 27
# completed run 48, 29
# completed run 48, 31
# completed run 48, 33
# CLOSED LOOP
# completed run 48, 35
# completed run 48, 40
# completed run 48, 41
# completed run 48, 46
# completed run 48, 47
# CLOSED LOOP
# completed run 48, 53
# completed run 48, 57
# completed run 48, 58
# completed run 48, 63
# CLOSED LOOP
# completed run 48, 64
# CLOSED LOOP
# completed run 48, 67
# CLOSED LOOP
# completed run 48, 70
# completed run 48, 72
# completed run 48, 77
# CLOSED LOOP
# completed run 48, 86
# completed run 48, 88
# CLOSED LOOP
# completed run 48, 89
# CLOSED LOOP
# completed run 48, 92
# completed run 48, 95
# completed run 48, 96
# completed run 48, 98
# completed run 48, 100
# CLOSED LOOP
# completed run 48, 103
# completed run 48, 105
# CLOSED LOOP
# completed run 48, 116
# CLOSED LOOP
# completed run 48, 119
# completed run 49, 3
# completed run 49, 19
# completed run 49, 22
# completed run 49, 23
# CLOSED LOOP
# completed run 49, 24
# completed run 49, 27
# completed run 49, 29
# completed run 49, 31
# completed run 49, 33
# CLOSED LOOP
# completed run 49, 35
# completed run 49, 40
# completed run 49, 41
# completed run 49, 46
# completed run 49, 47
# CLOSED LOOP
# completed run 49, 53
# CLOSED LOOP
# completed run 49, 57
# completed run 49, 58
# CLOSED LOOP
# completed run 49, 63
# CLOSED LOOP
# completed run 49, 64
# CLOSED LOOP
# completed run 49, 67
# CLOSED LOOP
# completed run 49, 70
# CLOSED LOOP
# completed run 49, 72
# CLOSED LOOP
# completed run 49, 77
# CLOSED LOOP
# completed run 49, 86
# completed run 49, 88
# CLOSED LOOP
# completed run 49, 89
# CLOSED LOOP
# completed run 49, 92
# completed run 49, 95
# completed run 49, 96
# CLOSED LOOP
# completed run 49, 98
# completed run 49, 100
# completed run 49, 103
# completed run 49, 105
# completed run 49, 116
# completed run 49, 119
# CLOSED LOOP
# completed run 50, 3
# CLOSED LOOP
# completed run 50, 19
# CLOSED LOOP
# completed run 50, 22
# completed run 50, 23
# completed run 50, 24
# completed run 50, 27
# CLOSED LOOP
# completed run 50, 29
# CLOSED LOOP
# completed run 50, 31
# completed run 50, 33
# CLOSED LOOP
# completed run 50, 35
# CLOSED LOOP
# completed run 50, 40
# completed run 50, 41
# CLOSED LOOP
# completed run 50, 46
# completed run 50, 47
# CLOSED LOOP
# completed run 50, 53
# CLOSED LOOP
# completed run 50, 57
# completed run 50, 58
# completed run 50, 63
# completed run 50, 64
# completed run 50, 67
# completed run 50, 70
# completed run 50, 72
# completed run 50, 77
# completed run 50, 86
# completed run 50, 88
# completed run 50, 89
# completed run 50, 92
# completed run 50, 95
# completed run 50, 96
# completed run 50, 98
# completed run 50, 100
# completed run 50, 103
# completed run 50, 105
# completed run 50, 116
# completed run 50, 119
# completed run 51, 3
# completed run 51, 19
# completed run 51, 22
# completed run 51, 23
# completed run 51, 24
# completed run 51, 27
# completed run 51, 29
# completed run 51, 31
# completed run 51, 33
# CLOSED LOOP
# completed run 51, 35
# completed run 51, 40
# completed run 51, 41
# completed run 51, 46
# completed run 51, 47
# CLOSED LOOP
# completed run 51, 53
# CLOSED LOOP
# completed run 51, 57
# completed run 51, 58
# completed run 51, 63
# CLOSED LOOP
# completed run 51, 64
# CLOSED LOOP
# completed run 51, 67
# completed run 51, 70
# completed run 51, 72
# completed run 51, 77
# CLOSED LOOP
# completed run 51, 86
# completed run 51, 88
# CLOSED LOOP
# completed run 51, 89
# CLOSED LOOP
# completed run 51, 92
# CLOSED LOOP
# completed run 51, 95
# completed run 51, 96
# completed run 51, 98
# completed run 51, 100
# completed run 51, 103
# completed run 51, 105
# CLOSED LOOP
# completed run 51, 116
# CLOSED LOOP
# completed run 51, 119
# completed run 52, 3
# completed run 52, 19
# completed run 52, 22
# completed run 52, 23
# completed run 52, 24
# completed run 52, 27
# completed run 52, 29
# completed run 52, 31
# completed run 52, 33
# CLOSED LOOP
# completed run 52, 35
# completed run 52, 40
# completed run 52, 41
# completed run 52, 46
# completed run 52, 47
# completed run 52, 53
# CLOSED LOOP
# completed run 52, 57
# completed run 52, 58
# completed run 52, 63
# CLOSED LOOP
# completed run 52, 64
# CLOSED LOOP
# completed run 52, 67
# CLOSED LOOP
# completed run 52, 70
# completed run 52, 72
# completed run 52, 77
# CLOSED LOOP
# completed run 52, 86
# completed run 52, 88
# CLOSED LOOP
# completed run 52, 89
# CLOSED LOOP
# completed run 52, 92
# completed run 52, 93
# completed run 52, 94
# CLOSED LOOP
# completed run 52, 95
# completed run 52, 96
# completed run 52, 97
# completed run 52, 98
# CLOSED LOOP
# completed run 52, 99
# completed run 52, 100
# CLOSED LOOP
# completed run 52, 101
# completed run 52, 102
# completed run 52, 103
# CLOSED LOOP
# completed run 52, 104
# completed run 52, 105
# CLOSED LOOP
# completed run 52, 106
# CLOSED LOOP
# completed run 52, 107
# completed run 52, 108
# completed run 52, 109
# CLOSED LOOP
# completed run 52, 110
# completed run 52, 111
# CLOSED LOOP
# completed run 52, 112
# completed run 52, 113
# CLOSED LOOP
# completed run 52, 114
# completed run 52, 115
# completed run 52, 116
# completed run 52, 117
# completed run 52, 118
# completed run 52, 119
# completed run 52, 120
# completed run 52, 121
# completed run 52, 122
# completed run 53, 3
# CLOSED LOOP
# completed run 53, 19
# CLOSED LOOP
# completed run 53, 20
# CLOSED LOOP
# completed run 53, 21
# completed run 53, 22
# completed run 53, 23
# CLOSED LOOP
# completed run 53, 24
# completed run 53, 25
# CLOSED LOOP
# completed run 53, 26
# completed run 53, 27
# completed run 53, 28
# completed run 53, 29
# CLOSED LOOP
# completed run 53, 30
# completed run 53, 31
# CLOSED LOOP
# completed run 53, 32
# completed run 53, 33
# completed run 53, 34
# completed run 53, 35
# completed run 53, 36
# completed run 53, 37
# CLOSED LOOP
# completed run 53, 38
# CLOSED LOOP
# completed run 53, 39
# completed run 53, 40
# completed run 53, 41
# CLOSED LOOP
# completed run 53, 42
# CLOSED LOOP
# completed run 53, 43
# completed run 53, 44
# completed run 53, 45
# CLOSED LOOP
# completed run 53, 46
# completed run 53, 47
# completed run 53, 48
# completed run 53, 49
# CLOSED LOOP
# ...
# completed run 105, 74
# completed run 105, 75
# completed run 105, 76
# completed run 105, 77
# completed run 105, 78
# completed run 105, 79
# completed run 105, 80
# completed run 105, 81
# completed run 105, 82
# completed run 105, 86
# completed run 105, 96
# completed run 105, 98
# completed run 105, 105
# CLOSED LOOP
# completed run 105, 111
# completed run 105, 113
# completed run 106, 12
# completed run 106, 29
# CLOSED LOOP
# completed run 106, 36
# completed run 106, 49
# CLOSED LOOP
# completed run 106, 53
# CLOSED LOOP
# completed run 106, 59
# completed run 106, 62
# completed run 106, 69
# completed run 106, 86
# completed run 106, 96
# completed run 106, 98
# completed run 106, 105
# completed run 106, 111
# completed run 106, 113
# CLOSED LOOP
# completed run 107, 12
# completed run 107, 29
# CLOSED LOOP
# completed run 107, 36
# completed run 107, 49
# completed run 107, 53
# CLOSED LOOP
# completed run 107, 59
# completed run 107, 62
# completed run 107, 69
# CLOSED LOOP
# completed run 107, 86
# CLOSED LOOP
# completed run 107, 96
# completed run 107, 98
# completed run 107, 105
# completed run 107, 111
# completed run 107, 113
# completed run 108, 12
# completed run 108, 29
# completed run 108, 36
# CLOSED LOOP
# completed run 108, 49
# CLOSED LOOP
# completed run 108, 53
# completed run 108, 59
# completed run 108, 62
# completed run 108, 69
# completed run 108, 86
# completed run 108, 96
# completed run 108, 98
# completed run 108, 105
# CLOSED LOOP
# completed run 108, 111
# completed run 108, 113
# completed run 109, 12
# completed run 109, 14
# CLOSED LOOP
# completed run 109, 15
# completed run 109, 16
# completed run 109, 17
# CLOSED LOOP
# completed run 109, 18
# completed run 109, 19
# completed run 109, 20
# completed run 109, 21
# CLOSED LOOP
# completed run 109, 22
# completed run 109, 23
# completed run 109, 24
# completed run 109, 25
# CLOSED LOOP
# completed run 109, 26
# CLOSED LOOP
# completed run 109, 27
# completed run 109, 28
# completed run 109, 29
# completed run 109, 30
# completed run 109, 31
# completed run 109, 32
# completed run 109, 33
# completed run 109, 34
# completed run 109, 35
# CLOSED LOOP
# completed run 109, 36
# CLOSED LOOP
# completed run 109, 37
# completed run 109, 38
# completed run 109, 39
# CLOSED LOOP
# completed run 109, 40
# completed run 109, 41
# completed run 109, 42
# CLOSED LOOP
# completed run 109, 43
# completed run 109, 44
# completed run 109, 45
# completed run 109, 46
# completed run 109, 47
# completed run 109, 48
# completed run 109, 49
# completed run 109, 50
# completed run 109, 51
# CLOSED LOOP
# completed run 109, 52
# CLOSED LOOP
# completed run 109, 53
# completed run 109, 54
# completed run 109, 55
# completed run 109, 56
# completed run 109, 57
# CLOSED LOOP
# completed run 109, 58
# completed run 109, 59
# CLOSED LOOP
# completed run 109, 60
# CLOSED LOOP
# completed run 109, 61
# completed run 109, 62
# CLOSED LOOP
# completed run 109, 63
# CLOSED LOOP
# completed run 109, 64
# CLOSED LOOP
# completed run 109, 65
# completed run 109, 66
# completed run 109, 67
# CLOSED LOOP
# completed run 109, 68
# completed run 109, 69
# completed run 109, 70
# completed run 109, 71
# completed run 109, 72
# completed run 109, 73
# CLOSED LOOP
# completed run 109, 74
# completed run 109, 75
# completed run 109, 76
# CLOSED LOOP
# completed run 109, 77
# completed run 109, 78
# CLOSED LOOP
# completed run 109, 79
# completed run 109, 80
# CLOSED LOOP
# completed run 109, 86
# completed run 109, 96
# completed run 109, 98
# completed run 109, 105
# CLOSED LOOP
# completed run 109, 111
# completed run 109, 113
# completed run 110, 12
# completed run 110, 14
# completed run 110, 29
# CLOSED LOOP
# completed run 110, 30
# completed run 110, 31
# CLOSED LOOP
# completed run 110, 32
# completed run 110, 33
# completed run 110, 34
# completed run 110, 35
# completed run 110, 36
# completed run 110, 37
# CLOSED LOOP
# completed run 110, 38
# CLOSED LOOP
# completed run 110, 39
# CLOSED LOOP
# completed run 110, 40
# CLOSED LOOP
# completed run 110, 41
# completed run 110, 42
# completed run 110, 43
# completed run 110, 44
# completed run 110, 45
# completed run 110, 46
# completed run 110, 47
# completed run 110, 48
# completed run 110, 49
# completed run 110, 50
# completed run 110, 51
# completed run 110, 52
# completed run 110, 53
# CLOSED LOOP
# completed run 110, 54
# CLOSED LOOP
# completed run 110, 55
# completed run 110, 56
# CLOSED LOOP
# completed run 110, 57
# CLOSED LOOP
# completed run 110, 58
# CLOSED LOOP
# completed run 110, 59
# CLOSED LOOP
# completed run 110, 62
# completed run 110, 69
# CLOSED LOOP
# completed run 110, 80
# completed run 110, 86
# completed run 110, 96
# completed run 110, 98
# completed run 110, 105
# completed run 110, 111
# completed run 110, 113
# completed run 111, 12
# completed run 111, 14
# CLOSED LOOP
# completed run 111, 36
# completed run 111, 49
# completed run 111, 53
# completed run 111, 62
# completed run 111, 69
# CLOSED LOOP
# completed run 111, 80
# CLOSED LOOP
# completed run 111, 86
# completed run 111, 96
# completed run 111, 98
# completed run 111, 105
# completed run 111, 111
# completed run 111, 113
# CLOSED LOOP
# completed run 112, 12
# completed run 112, 14
# CLOSED LOOP
# completed run 112, 36
# CLOSED LOOP
# completed run 112, 49
# CLOSED LOOP
# completed run 112, 53
# completed run 112, 62
# completed run 112, 69
# completed run 112, 70
# completed run 112, 71
# completed run 112, 72
# completed run 112, 73
# completed run 112, 74
# completed run 112, 75
# completed run 112, 76
# completed run 112, 77
# completed run 112, 78
# completed run 112, 79
# completed run 112, 80
# completed run 112, 81
# completed run 112, 82
# completed run 112, 83
# completed run 112, 84
# completed run 112, 85
# completed run 112, 86
# completed run 112, 87
# completed run 112, 88
# completed run 112, 89
# completed run 112, 90
# completed run 112, 91
# completed run 112, 92
# CLOSED LOOP
# completed run 112, 93
# completed run 112, 94
# completed run 112, 95
# completed run 112, 96
# completed run 112, 97
# completed run 112, 98
# completed run 112, 105
# CLOSED LOOP
# completed run 112, 111
# completed run 112, 113
# completed run 113, 12
# completed run 113, 14
# CLOSED LOOP
# completed run 113, 36
# completed run 113, 49
# CLOSED LOOP
# completed run 113, 53
# completed run 113, 62
# CLOSED LOOP
# completed run 113, 80
# CLOSED LOOP
# completed run 113, 86
# CLOSED LOOP
# completed run 113, 96
# CLOSED LOOP
# completed run 113, 105
# CLOSED LOOP
# completed run 113, 111
# CLOSED LOOP
# completed run 113, 113
# completed run 114, 12
# completed run 114, 14
# CLOSED LOOP
# completed run 114, 36
# completed run 114, 49
# CLOSED LOOP
# completed run 114, 53
# completed run 114, 62
# CLOSED LOOP
# completed run 114, 80
# CLOSED LOOP
# completed run 114, 82
# completed run 114, 83
# completed run 114, 84
# completed run 114, 85
# completed run 114, 86
# CLOSED LOOP
# completed run 114, 87
# completed run 114, 96
# CLOSED LOOP
# completed run 114, 97
# completed run 114, 98
# completed run 114, 99
# completed run 114, 100
# completed run 114, 101
# completed run 114, 102
# completed run 114, 103
# completed run 114, 104
# completed run 114, 105
# completed run 114, 106
# completed run 114, 107
# completed run 114, 108
# completed run 114, 109
# CLOSED LOOP
# completed run 114, 110
# completed run 114, 111
# completed run 114, 112
# completed run 114, 113
# completed run 115, 12
# completed run 115, 14
# completed run 115, 36
# completed run 115, 49
# completed run 115, 53
# completed run 115, 62
# completed run 115, 73
# CLOSED LOOP
# completed run 115, 74
# CLOSED LOOP
# completed run 115, 75
# completed run 115, 76
# CLOSED LOOP
# completed run 115, 77
# completed run 115, 78
# CLOSED LOOP
# completed run 115, 79
# CLOSED LOOP
# completed run 115, 80
# CLOSED LOOP
# completed run 115, 81
# CLOSED LOOP
# completed run 115, 82
# completed run 115, 83
# completed run 115, 84
# completed run 115, 85
# CLOSED LOOP
# completed run 115, 86
# CLOSED LOOP
# completed run 115, 87
# completed run 115, 88
# CLOSED LOOP
# completed run 115, 89
# CLOSED LOOP
# completed run 115, 105
# CLOSED LOOP
# completed run 115, 111
# completed run 116, 12
# completed run 116, 14
# completed run 116, 36
# completed run 116, 49
# completed run 116, 53
# completed run 116, 62
# completed run 116, 73
# completed run 116, 80
# completed run 116, 82
# completed run 116, 86
# completed run 116, 87
# completed run 116, 89
# completed run 116, 105
# completed run 116, 111
# completed run 117, 12
# completed run 117, 13
# CLOSED LOOP
# completed run 117, 14
# completed run 117, 15
# completed run 117, 16
# completed run 117, 17
# completed run 117, 18
# completed run 117, 19
# completed run 117, 20
# completed run 117, 21
# completed run 117, 22
# completed run 117, 23
# completed run 117, 24
# completed run 117, 25
# CLOSED LOOP
# completed run 117, 26
# completed run 117, 27
# CLOSED LOOP
# completed run 117, 28
# completed run 117, 29
# completed run 117, 30
# completed run 117, 31
# CLOSED LOOP
# completed run 117, 32
# completed run 117, 33
# completed run 117, 34
# CLOSED LOOP
# completed run 117, 35
# completed run 117, 36
# completed run 117, 37
# CLOSED LOOP
# completed run 117, 38
# CLOSED LOOP
# completed run 117, 39
# CLOSED LOOP
# completed run 117, 40
# CLOSED LOOP
# completed run 117, 41
# completed run 117, 42
# completed run 117, 43
# completed run 117, 44
# completed run 117, 45
# completed run 117, 46
# completed run 117, 47
# completed run 117, 48
# completed run 117, 49
# completed run 117, 50
# completed run 117, 51
# completed run 117, 52
# completed run 117, 53
# CLOSED LOOP
# completed run 117, 54
# CLOSED LOOP
# completed run 117, 55
# completed run 117, 56
# CLOSED LOOP
# completed run 117, 57
# completed run 117, 58
# completed run 117, 59
# CLOSED LOOP
# completed run 117, 60
# CLOSED LOOP
# completed run 117, 61
# completed run 117, 62
# completed run 117, 63
# completed run 117, 64
# CLOSED LOOP
# completed run 117, 65
# completed run 117, 66
# completed run 117, 67
# CLOSED LOOP
# completed run 117, 68
# completed run 117, 69
# CLOSED LOOP
# completed run 117, 70
# completed run 117, 71
# completed run 117, 72
# CLOSED LOOP
# completed run 117, 73
# completed run 117, 74
# completed run 117, 75
# CLOSED LOOP
# completed run 117, 76
# completed run 117, 77
# completed run 117, 78
# CLOSED LOOP
# completed run 117, 79
# completed run 117, 80
# completed run 117, 81
# completed run 117, 82
# CLOSED LOOP
# completed run 117, 83
# completed run 117, 84
# CLOSED LOOP
# completed run 117, 85
# completed run 117, 86
# CLOSED LOOP
# completed run 117, 87
# CLOSED LOOP
# completed run 117, 89
# completed run 117, 105
# completed run 117, 111
# completed run 118, 14
# CLOSED LOOP
# completed run 118, 36
# completed run 118, 49
# CLOSED LOOP
# completed run 118, 53
# completed run 118, 62
# completed run 118, 73
# CLOSED LOOP
# completed run 118, 80
# CLOSED LOOP
# completed run 118, 82
# CLOSED LOOP
# completed run 118, 87
# CLOSED LOOP
# completed run 118, 89
# completed run 118, 105
# CLOSED LOOP
# completed run 118, 111
# CLOSED LOOP
# completed run 119, 14
# CLOSED LOOP
# completed run 119, 36
# completed run 119, 49
# completed run 119, 53
# completed run 119, 62
# completed run 119, 73
# CLOSED LOOP
# completed run 119, 80
# completed run 119, 82
# CLOSED LOOP
# completed run 119, 87
# completed run 119, 89
# completed run 119, 105
# completed run 119, 111
# CLOSED LOOP
# completed run 120, 14
# CLOSED LOOP
# completed run 120, 15
# completed run 120, 16
# completed run 120, 17
# completed run 120, 18
# completed run 120, 19
# completed run 120, 20
# completed run 120, 21
# completed run 120, 22
# completed run 120, 23
# completed run 120, 24
# completed run 120, 25
# CLOSED LOOP
# completed run 120, 26
# completed run 120, 27
# CLOSED LOOP
# completed run 120, 28
# completed run 120, 29
# completed run 120, 30
# completed run 120, 31
# CLOSED LOOP
# completed run 120, 32
# completed run 120, 33
# CLOSED LOOP
# completed run 120, 34
# CLOSED LOOP
# completed run 120, 35
# CLOSED LOOP
# completed run 120, 36
# completed run 120, 49
# completed run 120, 53
# completed run 120, 62
# completed run 120, 63
# completed run 120, 64
# CLOSED LOOP
# completed run 120, 65
# completed run 120, 66
# completed run 120, 67
# CLOSED LOOP
# completed run 120, 68
# completed run 120, 69
# completed run 120, 70
# completed run 120, 71
# completed run 120, 72
# CLOSED LOOP
# completed run 120, 73
# completed run 120, 74
# completed run 120, 75
# completed run 120, 76
# completed run 120, 77
# completed run 120, 78
# completed run 120, 79
# completed run 120, 80
# completed run 120, 81
# completed run 120, 82
# completed run 120, 83
# completed run 120, 84
# completed run 120, 85
# completed run 120, 86
# completed run 120, 87
# completed run 120, 88
# completed run 120, 89
# completed run 120, 90
# completed run 120, 91
# completed run 120, 92
# completed run 120, 93
# completed run 120, 94
# CLOSED LOOP
# completed run 120, 95
# CLOSED LOOP
# completed run 120, 96
# CLOSED LOOP
# completed run 120, 97
# completed run 120, 98
# completed run 120, 99
# completed run 120, 100
# completed run 120, 101
# completed run 120, 102
# completed run 120, 103
# completed run 120, 104
# completed run 120, 105
# completed run 120, 111
# completed run 121, 49
# CLOSED LOOP
# completed run 121, 53
# completed run 121, 73
# CLOSED LOOP
# completed run 121, 80
# completed run 121, 82
# CLOSED LOOP
# completed run 121, 87
# CLOSED LOOP
# completed run 121, 89
# CLOSED LOOP
# completed run 121, 111
# completed run 122, 49
# CLOSED LOOP
# completed run 122, 53
# CLOSED LOOP
# completed run 122, 73
# completed run 122, 74
# completed run 122, 75
# CLOSED LOOP
# completed run 122, 76
# completed run 122, 77
# completed run 122, 78
# CLOSED LOOP
# completed run 122, 79
# completed run 122, 80
# completed run 122, 81
# completed run 122, 82
# CLOSED LOOP
# completed run 122, 83
# CLOSED LOOP
# completed run 122, 84
# completed run 122, 85
# completed run 122, 86
# completed run 122, 87
# completed run 122, 88
# completed run 122, 89
# completed run 122, 90
# CLOSED LOOP
# completed run 122, 91
# CLOSED LOOP
# completed run 122, 92
# completed run 122, 93
# completed run 122, 94
# CLOSED LOOP
# completed run 122, 95
# CLOSED LOOP
# completed run 122, 96
# CLOSED LOOP
# completed run 122, 97
# completed run 122, 98
# completed run 122, 99
# completed run 122, 100
# CLOSED LOOP
# completed run 122, 101
# completed run 122, 102
# completed run 122, 103
# completed run 122, 104
# CLOSED LOOP
# completed run 122, 105
# completed run 122, 106
# completed run 122, 107
# completed run 122, 108
# completed run 122, 109
# CLOSED LOOP
# completed run 122, 110
# CLOSED LOOP
# completed run 122, 111
# completed run 123, 49
# completed run 123, 53
# completed run 123, 80
# completed run 123, 82
# CLOSED LOOP
# completed run 123, 87
# CLOSED LOOP
# completed run 123, 89
# completed run 124, 49
# completed run 124, 50
# completed run 124, 51
# completed run 124, 52
# completed run 124, 53
# completed run 124, 54
# completed run 124, 55
# CLOSED LOOP
# completed run 124, 56
# CLOSED LOOP
# completed run 124, 57
# completed run 124, 58
# completed run 124, 59
# completed run 124, 60
# completed run 124, 61
# completed run 124, 62
# completed run 124, 63
# CLOSED LOOP
# completed run 124, 64
# CLOSED LOOP
# completed run 124, 65
# CLOSED LOOP
# completed run 124, 66
# CLOSED LOOP
# completed run 124, 67
# CLOSED LOOP
# completed run 124, 68
# CLOSED LOOP
# completed run 124, 69
# CLOSED LOOP
# completed run 124, 70
# completed run 124, 71
# completed run 124, 72
# completed run 124, 73
# completed run 124, 74
# completed run 124, 75
# CLOSED LOOP
# completed run 124, 76
# completed run 124, 77
# completed run 124, 78
# CLOSED LOOP
# completed run 124, 79
# completed run 124, 80
# completed run 124, 82
# completed run 124, 87
# completed run 124, 89
# completed run 125, 53
# completed run 125, 82
# CLOSED LOOP
# completed run 125, 87
# CLOSED LOOP
# completed run 125, 89
# CLOSED LOOP
# completed run 126, 53
# completed run 126, 54
# completed run 126, 55
# CLOSED LOOP
# completed run 126, 56
# CLOSED LOOP
# completed run 126, 57
# completed run 126, 58
# CLOSED LOOP
# completed run 126, 59
# completed run 126, 60
# completed run 126, 61
# completed run 126, 62
# completed run 126, 63
# CLOSED LOOP
# completed run 126, 64
# CLOSED LOOP
# completed run 126, 65
# CLOSED LOOP
# completed run 126, 66
# CLOSED LOOP
# completed run 126, 67
# CLOSED LOOP
# completed run 126, 68
# CLOSED LOOP
# completed run 126, 69
# CLOSED LOOP
# completed run 126, 70
# completed run 126, 71
# completed run 126, 72
# completed run 126, 73
# CLOSED LOOP
# completed run 126, 74
# completed run 126, 75
# CLOSED LOOP
# completed run 126, 76
# completed run 126, 77
# completed run 126, 78
# completed run 126, 79
# completed run 126, 80
# CLOSED LOOP
# completed run 126, 81
# completed run 126, 82
# CLOSED LOOP
# completed run 126, 83
# CLOSED LOOP
# completed run 126, 84
# CLOSED LOOP
# completed run 126, 85
# CLOSED LOOP
# completed run 126, 86
# CLOSED LOOP
# completed run 126, 87
# completed run 126, 89
# completed run 127, 82
# completed run 127, 89
# completed run 128, 82
# completed run 128, 83
# CLOSED LOOP
# completed run 128, 84
# completed run 128, 85
# completed run 128, 86
# completed run 128, 87
# completed run 128, 88
# completed run 128, 89
# 1671
