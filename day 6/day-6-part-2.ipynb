# %% [markdown]
# --- Part Two ---
# While The Historians begin working around the guard's patrol route, you borrow their fancy device and step outside the lab. From the safety of a supply closet, you time travel through the last few months and record the nightly status of the lab's guard post on the walls of the closet.
#
# Returning after what seems like only a few seconds to The Historians, they explain that the guard's patrol area is simply too large for them to safely search the lab without getting caught.
#
# Fortunately, they are pretty sure that adding a single new obstruction won't cause a time paradox. They'd like to place the new obstruction in such a way that the guard will get stuck in a loop, making the rest of the lab safe to search.
#
# To have the lowest chance of creating a time paradox, The Historians would like to know all of the possible positions for such an obstruction. The new obstruction can't be placed at the guard's starting position - the guard is there right now and would notice.
#
# In the above example, there are only 6 different positions where a new obstruction would cause the guard to get stuck in a loop. The diagrams of these six situations use O to mark the new obstruction, | to show a position where the guard moves up/down, - to show a position where the guard moves left/right, and + to show a position where the guard moves both up/down and left/right.

# %%
guard_characters = ["^", ">", "V", "<"]
pathing_chars = ["-", "|", "+"]
initial_grid = [
    "....#.....",
    ".........#",
    "..........",
    "..#.......",
    ".......#..",
    "..........",
    ".#..^.....",
    "........#.",
    "#.........",
    "......#...",
]
initial_grid = [list(row) for row in initial_grid]
initial_guard_loc_x = 0
initial_guard_loc_y = 0
initial_guard_direction = "^"

# %%
def get_file_content():
    with open("day-6-input.txt", "r") as file:
        # Read all lines and strip any trailing newlines or spaces
        grid = [line.strip() for line in file]
        grid = [list(row) for row in grid]
    return grid


initial_grid = get_file_content()

# %%
for y in range(len(initial_grid)):
    for x in range(len(initial_grid[y])):
        if initial_grid[y][x] in guard_characters:
            initial_guard_loc_x = x
            initial_guard_loc_y = y
            initial_guard_direction = initial_grid[y][x]


def get_movement_dir(guard_dir):
    match guard_dir:
        case "^":
            return (0, -1, "|")
        case ">":
            return (1, 0, "-")
        case "V":
            return (0, 1, "|")
        case "<":
            return (-1, 0, "-")
        case _:
            return (0, 0, ".")


def get_lookahead(guard_loc_x, guard_loc_y, offset, grid, reference_char=["#"]):
    value = grid[guard_loc_y + offset[1]][guard_loc_x + offset[0]]
    if len(reference_char) == 1:
      return value != reference_char[0]
    return value not in reference_char


def get_next_direction(guard_direction):
    index_of_direction = guard_characters.index(guard_direction)
    try:
        return guard_characters[index_of_direction + 1]
    except IndexError:
        return guard_characters[0]


def mutate_grid(x, y, grid, char):
    grid[y][x] = char
    return grid


def change_to_tracked(guard_loc_x, guard_loc_y, grid, direction_character):
    current_char = grid[guard_loc_y][guard_loc_x]
    if current_char in pathing_chars:
        direction_character = "+"
    grid = mutate_grid(guard_loc_x, guard_loc_y, grid, direction_character)
    return grid


def print_grid(grid):
    for line in grid:
        print(line)
    print("-----------")


def move_forward(guard_loc_x, guard_loc_y, guard_direction, grid, loop_references):
    offset = (0, 0, ".")
    can_move_forward = False
    has_turned = False
    while can_move_forward == False:
        offset = get_movement_dir(guard_direction)
        can_move_forward = get_lookahead(
            guard_loc_x, guard_loc_y, offset, grid, ["#", "O"]
        )
        if can_move_forward == False:
            has_turned = True
            guard_direction = get_next_direction(guard_direction)
            if (guard_loc_y, guard_loc_x, guard_direction) in loop_references:
                raise Exception("Closed loop")
            else:
                loop_references.append((guard_loc_y, guard_loc_x, guard_direction))
            
           

    grid = change_to_tracked(
        guard_loc_x, guard_loc_y, grid, "+" if has_turned else offset[2]
    )
    guard_loc_y = guard_loc_y + offset[1]
    guard_loc_x = guard_loc_x + offset[0]
    return (guard_loc_x, guard_loc_y, guard_direction, grid, loop_references)

# %%
import copy


def run_full_analysis(guard_loc_x, guard_loc_y, guard_direction, grid):
    loop_references = []
    loop_found = False
    while True:
        try:
            guard_loc_x, guard_loc_y, guard_direction, grid, loop_references = (
                move_forward(
                    guard_loc_x, guard_loc_y, guard_direction, grid, loop_references
                )
            )
        except IndexError:
            dir_char = get_movement_dir(guard_direction)
            grid = change_to_tracked(guard_loc_x, guard_loc_y, grid, dir_char[2])
            break
        except Exception as e:
            loop_found = True
            break
        
    if loop_found:
        return (1, grid)

    return (0, grid)

# %%
end_count = 0
end_count, check_grid = run_full_analysis(
    initial_guard_loc_x, initial_guard_loc_y, initial_guard_direction, copy.deepcopy(initial_grid)
)

# %%
for y in range(len(initial_grid)):
    print(f"completed run {y}, {end_count} loops found")
    for x in range(len(initial_grid[y])):
        if check_grid[y][x] in pathing_chars:
            if y == initial_guard_loc_x and x == initial_guard_loc_y:
                continue
            grid, guard_loc_x, guard_loc_y, guard_direction = (
                copy.deepcopy(initial_grid),
                initial_guard_loc_x,
                initial_guard_loc_y,
                initial_guard_direction,
            )
            grid = mutate_grid(x, y, grid, "O")
            outcome, grid = run_full_analysis(
                guard_loc_x, guard_loc_y, guard_direction, grid
            )
            end_count += outcome


print(end_count)
# Out:
# completed run 0, 0 loops found
# completed run 1, 0 loops found
# completed run 2, 0 loops found
# completed run 3, 0 loops found
# completed run 4, 0 loops found
# completed run 5, 21 loops found
# completed run 6, 22 loops found
# completed run 7, 58 loops found
# completed run 8, 58 loops found
# completed run 9, 77 loops found
# completed run 10, 104 loops found
# completed run 11, 105 loops found
# completed run 12, 106 loops found
# completed run 13, 107 loops found
# completed run 14, 145 loops found
# completed run 15, 146 loops found
# completed run 16, 149 loops found
# completed run 17, 160 loops found
# completed run 18, 164 loops found
# completed run 19, 192 loops found
# completed run 20, 197 loops found
# completed run 21, 227 loops found
# completed run 22, 240 loops found
# completed run 23, 260 loops found
# completed run 24, 265 loops found
# completed run 25, 271 loops found
# completed run 26, 279 loops found
# completed run 27, 287 loops found
# completed run 28, 322 loops found
# completed run 29, 335 loops found
# completed run 30, 348 loops found
# completed run 31, 357 loops found
# completed run 32, 381 loops found
# completed run 33, 390 loops found
# completed run 34, 401 loops found
# completed run 35, 409 loops found
# completed run 36, 462 loops found
# completed run 37, 480 loops found
# completed run 38, 505 loops found
# completed run 39, 521 loops found
# completed run 40, 542 loops found
# completed run 41, 566 loops found
# completed run 42, 577 loops found
# completed run 43, 599 loops found
# completed run 44, 605 loops found
# completed run 45, 618 loops found
# completed run 46, 625 loops found
# completed run 47, 628 loops found
# completed run 48, 676 loops found
# completed run 49, 687 loops found
# completed run 50, 701 loops found
# completed run 51, 711 loops found
# completed run 52, 722 loops found
# completed run 53, 739 loops found
# completed run 54, 769 loops found
# completed run 55, 779 loops found
# completed run 56, 785 loops found
# completed run 57, 790 loops found
# completed run 58, 796 loops found
# completed run 59, 804 loops found
# completed run 60, 805 loops found
# completed run 61, 828 loops found
# completed run 62, 850 loops found
# completed run 63, 875 loops found
# completed run 64, 882 loops found
# completed run 65, 890 loops found
# completed run 66, 898 loops found
# completed run 67, 901 loops found
# completed run 68, 947 loops found
# completed run 69, 948 loops found
# completed run 70, 958 loops found
# completed run 71, 975 loops found
# completed run 72, 1007 loops found
# completed run 73, 1014 loops found
# completed run 74, 1040 loops found
# completed run 75, 1065 loops found
# completed run 76, 1083 loops found
# completed run 77, 1094 loops found
# completed run 78, 1100 loops found
# completed run 79, 1146 loops found
# completed run 80, 1171 loops found
# completed run 81, 1186 loops found
# completed run 82, 1202 loops found
# completed run 83, 1213 loops found
# completed run 84, 1237 loops found
# completed run 85, 1246 loops found
# completed run 86, 1273 loops found
# completed run 87, 1288 loops found
# completed run 88, 1309 loops found
# completed run 89, 1320 loops found
# completed run 90, 1331 loops found
# completed run 91, 1335 loops found
# completed run 92, 1344 loops found
# completed run 93, 1359 loops found
# completed run 94, 1363 loops found
# completed run 95, 1373 loops found
# completed run 96, 1382 loops found
# completed run 97, 1390 loops found
# completed run 98, 1397 loops found
# completed run 99, 1403 loops found
# completed run 100, 1415 loops found
# completed run 101, 1425 loops found
# completed run 102, 1437 loops found
# completed run 103, 1454 loops found
# completed run 104, 1465 loops found
# completed run 105, 1473 loops found
# completed run 106, 1484 loops found
# completed run 107, 1487 loops found
# completed run 108, 1492 loops found
# completed run 109, 1495 loops found
# completed run 110, 1518 loops found
# completed run 111, 1531 loops found
# completed run 112, 1534 loops found
# completed run 113, 1540 loops found
# completed run 114, 1548 loops found
# completed run 115, 1555 loops found
# completed run 116, 1567 loops found
# completed run 117, 1567 loops found
# completed run 118, 1591 loops found
# completed run 119, 1598 loops found
# completed run 120, 1602 loops found
# completed run 121, 1616 loops found
# completed run 122, 1621 loops found
# completed run 123, 1636 loops found
# completed run 124, 1638 loops found
# completed run 125, 1649 loops found
# completed run 126, 1651 loops found
# completed run 127, 1670 loops found
# completed run 128, 1670 loops found
# completed run 129, 1671 loops found
# 1671
